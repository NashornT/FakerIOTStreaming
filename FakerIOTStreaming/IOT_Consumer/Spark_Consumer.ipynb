# %% [markdown]
# # **Instala Spark e Pub/Sub**

# %%
# !pip install google-cloud-pubsub
# !pip install google-cloud-storage
# !pip install gcsfs
# Out:
# Requirement already satisfied: google-cloud-pubsub in /opt/conda/lib/python3.11/site-packages (2.23.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.51.3 in /opt/conda/lib/python3.11/site-packages (from google-cloud-pubsub) (1.66.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-pubsub) (2.35.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in /opt/conda/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (2.20.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-pubsub) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-pubsub) (5.28.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.11/site-packages (from google-cloud-pubsub) (0.13.1)
# Requirement already satisfied: grpcio-status>=1.33.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-pubsub) (1.66.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (1.65.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/conda/lib/python3.11/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-pubsub) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-pubsub) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-pubsub) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-pubsub) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-pubsub) (2023.7.22)
# Requirement already satisfied: google-cloud-storage in /opt/conda/lib/python3.11/site-packages (2.18.2)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage) (2.35.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage) (2.20.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage) (2.31.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage) (1.6.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (5.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2023.7.22)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage) (0.6.1)
# Requirement already satisfied: gcsfs in /opt/conda/lib/python3.11/site-packages (2024.9.0.post1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from gcsfs) (3.10.7)
# Requirement already satisfied: decorator>4.1.2 in /opt/conda/lib/python3.11/site-packages (from gcsfs) (5.1.1)
# Requirement already satisfied: fsspec==2024.9.0 in /opt/conda/lib/python3.11/site-packages (from gcsfs) (2024.9.0)
# Requirement already satisfied: google-auth>=1.2 in /opt/conda/lib/python3.11/site-packages (from gcsfs) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib in /opt/conda/lib/python3.11/site-packages (from gcsfs) (1.2.1)
# Requirement already satisfied: google-cloud-storage in /opt/conda/lib/python3.11/site-packages (from gcsfs) (2.18.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from gcsfs) (2.31.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (2.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs) (1.13.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.11/site-packages (from google-auth-oauthlib->gcsfs) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage->gcsfs) (2.20.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage->gcsfs) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage->gcsfs) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.11/site-packages (from google-cloud-storage->gcsfs) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->gcsfs) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->gcsfs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->gcsfs) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->gcsfs) (2023.7.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.65.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (5.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/conda/lib/python3.11/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs) (1.24.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs) (3.2.2)

# %% [markdown]
# # **Define as Variavies de Ambiente**

# %%
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"iot-faker-spark-37582a9f1fac.json"

# %%
from pyspark.sql import SparkSession
import matplotlib.pyplot as plt
from pyspark.sql.functions import col, explode, avg, stddev, max, min, date_format, to_date
from pyspark.sql.types import *
import json
from datetime import datetime
from google.cloud import storage

# %%
csv_file = f'Data/{datetime.now()}.csv'

# %% [markdown]
# # **Realiza a Coleta, Transformação e Analise dos Dados IOT**

# %%
# Criar a sessão Spark

spark = SparkSession.builder.appName("IoTDataProcessing").\
config("spark.jars.packages", "com.google.cloud.bigdataoss:gcs-connector:hadoop3-2.2.5")\
.master("local").getOrCreate()

# %%
project_id = "" # Seu Projeto
subscription_id = "" # Sua  Inscriçâo 

# Configurar o caminho do bucket
bucket_name = "" # Seu Bucket


# Definir o esquema para 'data'
data_schema = StructType([
    StructField("temperature", IntegerType(), True),
    StructField("humidity", IntegerType(), True)
])

# Definir o esquema para 'device_data'
device_schema = StructType([
    StructField("device_id", StringType(), True),
    StructField("timestamp", StringType(), True),
    StructField("date", StringType(), True),
    StructField("status", StringType(), True),
    StructField("data", data_schema, True)
])

# Definir o esquema do JSON principal
main_schema = StructType([
    StructField("batch_id", StringType(), True),
    StructField("timestamp", StringType(), True),
    StructField("device_data", ArrayType(device_schema), True)
])

# %%
def upload_to_gcs(bucket_name, source_file_name, destination_blob_name):
    """Envia um arquivo para o bucket GCS especificado."""
    # Cria um cliente do GCS
    storage_client = storage.Client()
    
    # Obtém o bucket
    bucket = storage_client.bucket(bucket_name)
    
    # Cria um blob no bucket
    blob = bucket.blob(destination_blob_name)
    
    # Faz o upload do arquivo para o blob
    blob.upload_from_filename(source_file_name)
    
    print(f"Arquivo {source_file_name} enviado para {destination_blob_name}.")

# %%
def analyze_data(df):
    # Calcular estatísticas básicas

    print("Mostrando estatísticas básicas")

    stats = df.groupBy().agg(
        avg("temperature").alias("avg_temperature"),
        avg("humidity").alias("avg_humidity"),
        stddev("temperature").alias("stddev_temperature"),
        stddev("humidity").alias("stddev_humidity"),
        max("temperature").alias("max_temperature"),
        min("temperature").alias("min_temperature"),
        max("humidity").alias("max_humidity"),
        min("humidity").alias("min_humidity")
    )

    stats.show(truncate=False)

def analyze_time_series(df):
    # Adicionar uma coluna de data
    df_with_date = df.withColumn("date", to_date(col("device_timestamp"), "HH:mm:ss"))

    # Agrupar por data e calcular a média
        
    print("Mostrando Status do dia")

    daily_stats = df_with_date.groupBy("date").agg(
        avg("temperature").alias("avg_temperature"),
        avg("humidity").alias("avg_humidity")
    )

    daily_stats.show(truncate=False)

def analyze_by_device(df):
    # Calcular a média de temperatura e umidade por dispositivo

    print("Mostrando média de temperatura e umidade por dispositivo")

    device_stats = df.groupBy("device_id").agg(
        avg("temperature").alias("avg_temperature"),
        avg("humidity").alias("avg_humidity")
    )

    device_stats.show(truncate=False)

# def plot_daily_temperature(df):
#     # Coletar dados como Pandas DataFrame para visualização
#     pandas_df = df.toPandas()

#     # Plotar dados
#     plt.figure(figsize=(12, 6))
#     plt.plot(pandas_df["date"], pandas_df["avg_temperature"], marker='o')
#     plt.title("Daily Average Temperature")
#     plt.xlabel("Date")
#     plt.ylabel("Average Temperature")
#     plt.grid(True)
#     plt.xticks(rotation=45)
#     plt.tight_layout()
#     plt.show()

def analyze_correlation(df):
    # Calcular a correlação entre temperatura e umidade
    correlation = df.stat.corr("temperature", "humidity")
    print(f"Correlation between temperature and humidity: {correlation}")

# %%
# Função para transformar a mensagem Pub/Sub em um DataFrame Spark
def pubsub_message_to_dataframe(messages):
    data = [json.loads(message.data.decode("utf-8")) for message in messages]
    return spark.createDataFrame(data, schema=main_schema)

# %%
# Lógica de Processamento
def process_iot_data(df):
    # Explodir a coluna 'device_data' para criar uma linha por dispositivo
    df_exploded = df.withColumn("device_data_exploded", explode("device_data"))

    # Selecionar e mapear as colunas
    df_mapped = df_exploded.select(
        col("batch_id"),
        col("timestamp"),
        col("device_data_exploded.device_id"),
        col("device_data_exploded.timestamp").alias("device_timestamp"),
        col("device_data_exploded.date"),
        col("device_data_exploded.status"),
        col("device_data_exploded.data.temperature"),
        col("device_data_exploded.data.humidity")
    )
    
    df_pandas = df_mapped.toPandas()

    csv_file = f'Data/{datetime.now()}.csv'
    df_pandas.to_csv(csv_file, index=False)
    upload_to_gcs("data-lake-iot",csv_file,f"IOT_DATA/{datetime.now()}.csv")
    


    # Exibir o esquema e uma amostra dos dados
    # df_mapped.printSchema()
    # df_mapped.show(truncate=False)

    # Executar análises
    analyze_data(df_mapped)
    analyze_time_series(df_mapped)
    analyze_by_device(df_mapped)
    analyze_correlation(df_mapped)

    # Plotar resultados
    daily_stats_df = analyze_time_series(df_mapped)
    #plot_daily_temperature(daily_stats_df)

# %%
# Inicia o consumidor
def start_subscriber():
    from google.cloud import pubsub_v1

    subscriber = pubsub_v1.SubscriberClient()
    subscription_path = subscriber.subscription_path(project_id, subscription_id)

    def callback(message):
        # Converte a mensagem Pub/Sub em um DataFrame Spark e processa
        df = pubsub_message_to_dataframe([message])
        process_iot_data(df)
        message.ack()

    # Configura o streaming listener
    streaming_pull_future = subscriber.subscribe(subscription_path, callback=callback)
    print(f"Listening for messages on {subscription_path}...")
    try:
        streaming_pull_future.result()
    except KeyboardInterrupt:
        streaming_pull_future.cancel()

# Inicia o processo de assinante Pub/Sub
start_subscriber()
# Out:
# Listening for messages on projects/iot-faker-spark/subscriptions/Spark-IOT...
# Arquivo Data/2024-10-17 23:22:39.687635.csv enviado para IOT_DATA/2024-10-17 23:22:39.690321.csv.
# Mostrando estatísticas básicas
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |avg_temperature|avg_humidity|stddev_temperature|stddev_humidity   |max_temperature|min_temperature|max_humidity|min_humidity|
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |49.35          |53.8        |18.073752413812397|21.350705645925323|78             |24             |80          |18          |
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
#
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|49.35          |53.8        |
# +----------+---------------+------------+
#
# Mostrando média de temperatura e umidade por dispositivo
# +---------+---------------+------------+
# |device_id|avg_temperature|avg_humidity|
# +---------+---------------+------------+
# |sensor7  |64.0           |80.0        |
# |sensor1  |67.0           |31.0        |
# |sensor10 |67.0           |73.0        |
# |sensor4  |57.0           |70.0        |
# |sensor5  |52.0           |61.0        |
# |sensor19 |51.0           |28.0        |
# |sensor8  |70.0           |75.0        |
# |sensor14 |76.0           |66.0        |
# |sensor3  |39.0           |63.0        |
# |sensor17 |29.0           |49.0        |
# |sensor12 |45.0           |70.0        |
# |sensor18 |39.0           |79.0        |
# |sensor15 |24.0           |72.0        |
# |sensor6  |78.0           |71.0        |
# |sensor0  |68.0           |18.0        |
# |sensor11 |31.0           |18.0        |
# |sensor2  |25.0           |51.0        |
# |sensor9  |38.0           |32.0        |
# |sensor13 |42.0           |41.0        |
# |sensor16 |25.0           |28.0        |
# +---------+---------------+------------+
#
# Correlation between temperature and humidity: 0.26097061367133134
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|49.35          |53.8        |
# +----------+---------------+------------+
#
# Arquivo Data/2024-10-17 23:24:42.715240.csv enviado para IOT_DATA/2024-10-17 23:24:42.716972.csv.
# Mostrando estatísticas básicas
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |avg_temperature|avg_humidity|stddev_temperature|stddev_humidity   |max_temperature|min_temperature|max_humidity|min_humidity|
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |50.5           |45.75       |18.760260350566902|19.571394270317345|79             |19             |80          |20          |
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
#
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|50.5           |45.75       |
# +----------+---------------+------------+
#
# Mostrando média de temperatura e umidade por dispositivo
# +---------+---------------+------------+
# |device_id|avg_temperature|avg_humidity|
# +---------+---------------+------------+
# |sensor7  |74.0           |30.0        |
# |sensor1  |19.0           |61.0        |
# |sensor10 |45.0           |32.0        |
# |sensor4  |20.0           |44.0        |
# |sensor5  |75.0           |69.0        |
# |sensor19 |30.0           |62.0        |
# |sensor8  |54.0           |72.0        |
# |sensor14 |39.0           |39.0        |
# |sensor3  |70.0           |53.0        |
# |sensor17 |79.0           |49.0        |
# |sensor12 |47.0           |66.0        |
# |sensor18 |34.0           |20.0        |
# |sensor15 |32.0           |47.0        |
# |sensor6  |53.0           |28.0        |
# |sensor0  |36.0           |22.0        |
# |sensor11 |70.0           |68.0        |
# |sensor2  |48.0           |26.0        |
# |sensor9  |62.0           |23.0        |
# |sensor13 |51.0           |24.0        |
# |sensor16 |72.0           |80.0        |
# +---------+---------------+------------+
#
# Correlation between temperature and humidity: 0.21451738445729168
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|50.5           |45.75       |
# +----------+---------------+------------+
#
# Arquivo Data/2024-10-17 23:26:42.495338.csv enviado para IOT_DATA/2024-10-17 23:26:42.496744.csv.
# Mostrando estatísticas básicas
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |avg_temperature|avg_humidity|stddev_temperature|stddev_humidity   |max_temperature|min_temperature|max_humidity|min_humidity|
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |42.75          |43.9        |20.086326849769957|16.945423229328107|78             |18             |73          |21          |
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
#
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|42.75          |43.9        |
# +----------+---------------+------------+
#
# Mostrando média de temperatura e umidade por dispositivo
# +---------+---------------+------------+
# |device_id|avg_temperature|avg_humidity|
# +---------+---------------+------------+
# |sensor7  |18.0           |56.0        |
# |sensor1  |44.0           |44.0        |
# |sensor10 |43.0           |29.0        |
# |sensor4  |18.0           |32.0        |
# |sensor5  |67.0           |58.0        |
# |sensor19 |39.0           |32.0        |
# |sensor8  |66.0           |71.0        |
# |sensor14 |40.0           |41.0        |
# |sensor3  |65.0           |48.0        |
# |sensor17 |30.0           |31.0        |
# |sensor12 |72.0           |23.0        |
# |sensor18 |54.0           |47.0        |
# |sensor15 |78.0           |69.0        |
# |sensor6  |28.0           |21.0        |
# |sensor0  |64.0           |37.0        |
# |sensor11 |34.0           |65.0        |
# |sensor2  |23.0           |29.0        |
# |sensor9  |18.0           |22.0        |
# |sensor13 |36.0           |73.0        |
# |sensor16 |18.0           |50.0        |
# +---------+---------------+------------+
#
# Correlation between temperature and humidity: 0.32093434148787225
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|42.75          |43.9        |
# +----------+---------------+------------+
#
# Arquivo Data/2024-10-17 23:28:42.957142.csv enviado para IOT_DATA/2024-10-17 23:28:42.958293.csv.
# Mostrando estatísticas básicas
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |avg_temperature|avg_humidity|stddev_temperature|stddev_humidity   |max_temperature|min_temperature|max_humidity|min_humidity|
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |50.45          |50.65       |16.8693899056686  |18.082486438249408|77             |19             |79          |20          |
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
#
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|50.45          |50.65       |
# +----------+---------------+------------+
#
# Mostrando média de temperatura e umidade por dispositivo
# +---------+---------------+------------+
# |device_id|avg_temperature|avg_humidity|
# +---------+---------------+------------+
# |sensor7  |34.0           |71.0        |
# |sensor1  |33.0           |60.0        |
# |sensor10 |61.0           |32.0        |
# |sensor4  |63.0           |47.0        |
# |sensor5  |70.0           |41.0        |
# |sensor19 |54.0           |78.0        |
# |sensor8  |65.0           |60.0        |
# |sensor14 |33.0           |79.0        |
# |sensor3  |77.0           |71.0        |
# |sensor17 |26.0           |58.0        |
# |sensor12 |58.0           |63.0        |
# |sensor18 |71.0           |58.0        |
# |sensor15 |32.0           |38.0        |
# |sensor6  |19.0           |20.0        |
# |sensor0  |70.0           |32.0        |
# |sensor11 |56.0           |27.0        |
# |sensor2  |41.0           |49.0        |
# |sensor9  |47.0           |65.0        |
# |sensor13 |46.0           |28.0        |
# |sensor16 |53.0           |36.0        |
# +---------+---------------+------------+
#
# Correlation between temperature and humidity: 0.025044128005345133
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|50.45          |50.65       |
# +----------+---------------+------------+
#
# Arquivo Data/2024-10-17 23:30:44.028489.csv enviado para IOT_DATA/2024-10-17 23:30:44.029368.csv.
# Mostrando estatísticas básicas
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |avg_temperature|avg_humidity|stddev_temperature|stddev_humidity   |max_temperature|min_temperature|max_humidity|min_humidity|
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |52.4           |53.75       |15.984861259131534|17.025909049074833|78             |18             |80          |23          |
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
#
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|52.4           |53.75       |
# +----------+---------------+------------+
#
# Mostrando média de temperatura e umidade por dispositivo
# +---------+---------------+------------+
# |device_id|avg_temperature|avg_humidity|
# +---------+---------------+------------+
# |sensor7  |18.0           |43.0        |
# |sensor1  |77.0           |55.0        |
# |sensor10 |68.0           |76.0        |
# |sensor4  |53.0           |56.0        |
# |sensor5  |66.0           |48.0        |
# |sensor19 |50.0           |72.0        |
# |sensor8  |52.0           |36.0        |
# |sensor14 |50.0           |58.0        |
# |sensor3  |60.0           |38.0        |
# |sensor17 |44.0           |80.0        |
# |sensor12 |67.0           |55.0        |
# |sensor18 |19.0           |60.0        |
# |sensor15 |34.0           |53.0        |
# |sensor6  |57.0           |57.0        |
# |sensor0  |45.0           |24.0        |
# |sensor11 |48.0           |76.0        |
# |sensor2  |48.0           |69.0        |
# |sensor9  |54.0           |23.0        |
# |sensor13 |78.0           |65.0        |
# |sensor16 |60.0           |31.0        |
# +---------+---------------+------------+
#
# Correlation between temperature and humidity: 0.04699303478011921
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|52.4           |53.75       |
# +----------+---------------+------------+
#
# Arquivo Data/2024-10-17 23:32:43.949115.csv enviado para IOT_DATA/2024-10-17 23:32:43.950579.csv.
# Mostrando estatísticas básicas
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |avg_temperature|avg_humidity|stddev_temperature|stddev_humidity   |max_temperature|min_temperature|max_humidity|min_humidity|
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
# |53.15          |45.85       |17.94516501368603 |17.275705484870944|78             |21             |77          |18          |
# +---------------+------------+------------------+------------------+---------------+---------------+------------+------------+
#
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|53.15          |45.85       |
# +----------+---------------+------------+
#
# Mostrando média de temperatura e umidade por dispositivo
# +---------+---------------+------------+
# |device_id|avg_temperature|avg_humidity|
# +---------+---------------+------------+
# |sensor7  |26.0           |51.0        |
# |sensor1  |27.0           |39.0        |
# |sensor10 |66.0           |18.0        |
# |sensor4  |67.0           |44.0        |
# |sensor5  |67.0           |64.0        |
# |sensor19 |41.0           |44.0        |
# |sensor8  |78.0           |61.0        |
# |sensor14 |55.0           |46.0        |
# |sensor3  |21.0           |22.0        |
# |sensor17 |55.0           |51.0        |
# |sensor12 |36.0           |67.0        |
# |sensor18 |53.0           |77.0        |
# |sensor15 |77.0           |53.0        |
# |sensor6  |62.0           |28.0        |
# |sensor0  |44.0           |45.0        |
# |sensor11 |27.0           |18.0        |
# |sensor2  |65.0           |27.0        |
# |sensor9  |63.0           |73.0        |
# |sensor13 |71.0           |45.0        |
# |sensor16 |62.0           |44.0        |
# +---------+---------------+------------+
#
# Correlation between temperature and humidity: 0.2506581877313904
# Mostrando Status do dia
# +----------+---------------+------------+
# |date      |avg_temperature|avg_humidity|
# +----------+---------------+------------+
# |1970-01-01|53.15          |45.85       |
# +----------+---------------+------------+
